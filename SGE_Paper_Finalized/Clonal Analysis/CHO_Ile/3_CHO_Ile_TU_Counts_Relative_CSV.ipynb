# %%
import numpy as np
import pandas as pd
import os
import glob

# Define paths
input_dir = '/Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs'
output_csv = '/Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_SummaryOutputs/CHO_Ile_RelativeReadCounts.csv'

# Ensure output directory exists
os.makedirs(os.path.dirname(output_csv), exist_ok=True)

# Get all input files
input_files = sorted(glob.glob(os.path.join(input_dir, 'Counts_BS*')))

# Define promoters and CDS
promoters = ['Ef1a', 'PGK']
mts_promoters = [f'{p}-MTS' for p in promoters]
cds = ['GFP', 'ilvA', 'ilvA mut 1', 'ilvA mut 2', 'ilvG', 'ilvM', 'ilvB', 'ilvN', 'ilvC', 'ilvD']

csv_data = []

for file_path in input_files:
    df = pd.read_csv(file_path, skiprows=13, names=['BC Number', 'BC Name', 'Sequence', 'Counts'])
    total_reads = df['Counts'].sum()
    norm = 100 / total_reads if total_reads > 0 else 0
    quality = 'Above_50000' if total_reads >= 50000 else 'Below_50000'

    print(f"File: {file_path}, Total Reads: {total_reads}, Normalization Value: {norm:.6f}, Read Quality: {quality}")

    # Filter for usable barcodes
    df_filtered = df[
        (~df['BC Name'].str.contains("Unassigned")) &
        (df['BC Name'].str.contains("Ef1a__|PGK__|CMV__|TightTRE__|NoProm__|Ef1a-MTS__|PGK-MTS__|CMV-MTS__|TightTRE-MTS__|NoProm-MTS__|__Ef1a|__PGK|__CMV|__TightTRE|__NoProm|__Ef1a-MTS|__PGK-MTS"))
    ]

    sum_TU = {}

    # Count regular (non-MTS) promoters
    for promoter in promoters:
        for cd in cds:
            match1 = df_filtered['BC Name'].str.contains(f"{cd}__{promoter}(?!-MTS)", regex=True)
            match2 = df_filtered['BC Name'].str.contains(f"{promoter}__{cd}(?!-MTS)", regex=True)
            sum_TU[f'{promoter}_{cd}'] = (df_filtered.loc[match1, 'Counts'].sum() + df_filtered.loc[match2, 'Counts'].sum()) * norm

    # Count MTS promoters
    for promoter in mts_promoters:
        for cd in cds:
            match1 = df_filtered['BC Name'].str.contains(f"{cd}__{promoter}")
            match2 = df_filtered['BC Name'].str.contains(f"{promoter}__{cd}")
            sum_TU[f'{promoter}_{cd}'] = (df_filtered.loc[match1, 'Counts'].sum() + df_filtered.loc[match2, 'Counts'].sum()) * norm

    # Add row to output
    row = {'File': os.path.basename(file_path), 'Read_Quality': quality}
    row.update(sum_TU)
    csv_data.append(row)

# Write to CSV
output_df = pd.DataFrame(csv_data)
output_df.to_csv(output_csv, index=False)
print(f"Summary saved to: {output_csv}")
# Out:
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28008A, Total Reads: 286938.0, Normalization Value: 0.000349, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28009A, Total Reads: 334868.0, Normalization Value: 0.000299, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28010A, Total Reads: 216622.0, Normalization Value: 0.000462, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28011A, Total Reads: 141438.0, Normalization Value: 0.000707, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28012A, Total Reads: 157716.0, Normalization Value: 0.000634, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28013A, Total Reads: 166937.0, Normalization Value: 0.000599, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28014A, Total Reads: 122259.0, Normalization Value: 0.000818, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28015A, Total Reads: 326938.0, Normalization Value: 0.000306, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28016A, Total Reads: 137771.0, Normalization Value: 0.000726, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28017A, Total Reads: 259800.0, Normalization Value: 0.000385, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28018A, Total Reads: 93645.0, Normalization Value: 0.001068, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28019A, Total Reads: 98888.0, Normalization Value: 0.001011, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28020A, Total Reads: 140958.0, Normalization Value: 0.000709, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28021A, Total Reads: 277728.0, Normalization Value: 0.000360, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28022A, Total Reads: 288389.0, Normalization Value: 0.000347, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28023A, Total Reads: 325609.0, Normalization Value: 0.000307, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28024A, Total Reads: 173394.0, Normalization Value: 0.000577, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28025A, Total Reads: 160863.0, Normalization Value: 0.000622, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28026A, Total Reads: 165483.0, Normalization Value: 0.000604, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28027A, Total Reads: 129910.0, Normalization Value: 0.000770, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28028A, Total Reads: 252109.0, Normalization Value: 0.000397, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28029A, Total Reads: 133522.0, Normalization Value: 0.000749, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28030A, Total Reads: 199352.0, Normalization Value: 0.000502, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28031A, Total Reads: 92870.0, Normalization Value: 0.001077, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28032A, Total Reads: 140183.0, Normalization Value: 0.000713, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28033A, Total Reads: 156087.0, Normalization Value: 0.000641, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28034A, Total Reads: 126283.0, Normalization Value: 0.000792, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28035A, Total Reads: 117285.0, Normalization Value: 0.000853, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28036A, Total Reads: 131035.0, Normalization Value: 0.000763, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28037A, Total Reads: 102011.0, Normalization Value: 0.000980, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28038A, Total Reads: 98102.0, Normalization Value: 0.001019, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28040A, Total Reads: 106667.0, Normalization Value: 0.000937, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28042A, Total Reads: 117714.0, Normalization Value: 0.000850, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28043A, Total Reads: 226919.0, Normalization Value: 0.000441, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28044A, Total Reads: 191933.0, Normalization Value: 0.000521, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28045A, Total Reads: 127464.0, Normalization Value: 0.000785, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28046A, Total Reads: 173260.0, Normalization Value: 0.000577, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28047A, Total Reads: 262959.0, Normalization Value: 0.000380, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28048A, Total Reads: 195916.0, Normalization Value: 0.000510, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28049A, Total Reads: 117799.0, Normalization Value: 0.000849, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28050A, Total Reads: 112842.0, Normalization Value: 0.000886, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28051A, Total Reads: 191263.0, Normalization Value: 0.000523, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28052A, Total Reads: 180428.0, Normalization Value: 0.000554, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28053A, Total Reads: 198969.0, Normalization Value: 0.000503, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28196A, Total Reads: 55668.0, Normalization Value: 0.001796, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_Counts/output_csvs/Counts_BS28197A, Total Reads: 51410.0, Normalization Value: 0.001945, Read Quality: Above_50000
# Summary saved to: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/CHO_Isoleucine/CHO_Isoleucine_SummaryOutputs/CHO_Ile_RelativeReadCounts.csv
