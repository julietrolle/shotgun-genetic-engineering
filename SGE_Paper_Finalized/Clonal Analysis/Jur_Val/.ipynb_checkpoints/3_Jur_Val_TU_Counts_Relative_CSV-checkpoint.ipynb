# %%
import numpy as np
import pandas as pd
import os
import glob

# Define paths
input_dir = '/Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs'
output_csv = '/Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_SummaryOutputs/Jurkat_Val_RelativeReadCounts.csv'

# Ensure output directory exists
os.makedirs(os.path.dirname(output_csv), exist_ok=True)

# Get all input files
input_files = sorted(glob.glob(os.path.join(input_dir, 'Counts_BS*')))

# Define promoters and CDS
promoters = ['Ef1a', 'PGK']
mts_promoters = [f'{p}-MTS' for p in promoters]
cds = ['GFP', 'ilvA', 'ilvA mut 1', 'ilvA mut 2', 'ilvG', 'ilvM', 'ilvB', 'ilvN', 'ilvC', 'ilvD']

csv_data = []

for file_path in input_files:
    df = pd.read_csv(file_path, skiprows=13, names=['BC Number', 'BC Name', 'Sequence', 'Counts'])
    total_reads = df['Counts'].sum()
    norm = 100 / total_reads if total_reads > 0 else 0
    quality = 'Above_50000' if total_reads >= 50000 else 'Below_50000'

    print(f"File: {file_path}, Total Reads: {total_reads}, Normalization Value: {norm:.6f}, Read Quality: {quality}")

    # Filter for usable barcodes
    df_filtered = df[
        (~df['BC Name'].str.contains("Unassigned")) &
        (df['BC Name'].str.contains("Ef1a__|PGK__|CMV__|TightTRE__|NoProm__|Ef1a-MTS__|PGK-MTS__|CMV-MTS__|TightTRE-MTS__|NoProm-MTS__|__Ef1a|__PGK|__CMV|__TightTRE|__NoProm|__Ef1a-MTS|__PGK-MTS"))
    ]

    sum_TU = {}

    # Count regular (non-MTS) promoters
    for promoter in promoters:
        for cd in cds:
            match1 = df_filtered['BC Name'].str.contains(f"{cd}__{promoter}(?!-MTS)", regex=True)
            match2 = df_filtered['BC Name'].str.contains(f"{promoter}__{cd}(?!-MTS)", regex=True)
            sum_TU[f'{promoter}_{cd}'] = (df_filtered.loc[match1, 'Counts'].sum() + df_filtered.loc[match2, 'Counts'].sum()) * norm

    # Count MTS promoters
    for promoter in mts_promoters:
        for cd in cds:
            match1 = df_filtered['BC Name'].str.contains(f"{cd}__{promoter}")
            match2 = df_filtered['BC Name'].str.contains(f"{promoter}__{cd}")
            sum_TU[f'{promoter}_{cd}'] = (df_filtered.loc[match1, 'Counts'].sum() + df_filtered.loc[match2, 'Counts'].sum()) * norm

    # Add row to output
    row = {'File': os.path.basename(file_path), 'Read_Quality': quality}
    row.update(sum_TU)
    csv_data.append(row)

# Write to CSV
output_df = pd.DataFrame(csv_data)
output_df.to_csv(output_csv, index=False)
print(f"Summary saved to: {output_csv}")
# Out:
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27976A, Total Reads: 238296.0, Normalization Value: 0.000420, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27977A, Total Reads: 184117.0, Normalization Value: 0.000543, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27978A, Total Reads: 624092.0, Normalization Value: 0.000160, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27979A, Total Reads: 377707.0, Normalization Value: 0.000265, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27980A, Total Reads: 175853.0, Normalization Value: 0.000569, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27981A, Total Reads: 411836.0, Normalization Value: 0.000243, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27982A, Total Reads: 415113.0, Normalization Value: 0.000241, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27983A, Total Reads: 672184.0, Normalization Value: 0.000149, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27984A, Total Reads: 331764.0, Normalization Value: 0.000301, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27985A, Total Reads: 479802.0, Normalization Value: 0.000208, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27986A, Total Reads: 311230.0, Normalization Value: 0.000321, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27987A, Total Reads: 103436.0, Normalization Value: 0.000967, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27988A, Total Reads: 97961.0, Normalization Value: 0.001021, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27989A, Total Reads: 405882.0, Normalization Value: 0.000246, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27990A, Total Reads: 391033.0, Normalization Value: 0.000256, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27991A, Total Reads: 454406.0, Normalization Value: 0.000220, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27992A, Total Reads: 212299.0, Normalization Value: 0.000471, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27993A, Total Reads: 456779.0, Normalization Value: 0.000219, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27994A, Total Reads: 388773.0, Normalization Value: 0.000257, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27995A, Total Reads: 302086.0, Normalization Value: 0.000331, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27996A, Total Reads: 2.0, Normalization Value: 50.000000, Read Quality: Below_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27997A, Total Reads: 214720.0, Normalization Value: 0.000466, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27998A, Total Reads: 0.0, Normalization Value: 0.000000, Read Quality: Below_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS27999A, Total Reads: 446306.0, Normalization Value: 0.000224, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28000A, Total Reads: 80022.0, Normalization Value: 0.001250, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28001A, Total Reads: 407141.0, Normalization Value: 0.000246, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28002A, Total Reads: 50302.0, Normalization Value: 0.001988, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28003A, Total Reads: 580862.0, Normalization Value: 0.000172, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28004A, Total Reads: 348833.0, Normalization Value: 0.000287, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28005A, Total Reads: 357839.0, Normalization Value: 0.000279, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28638A, Total Reads: 332097.0, Normalization Value: 0.000301, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28639A, Total Reads: 357506.0, Normalization Value: 0.000280, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28640A, Total Reads: 20996.0, Normalization Value: 0.004763, Read Quality: Below_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28641A, Total Reads: 240122.0, Normalization Value: 0.000416, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28642A, Total Reads: 193639.0, Normalization Value: 0.000516, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28643A, Total Reads: 279029.0, Normalization Value: 0.000358, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28644A, Total Reads: 49244.0, Normalization Value: 0.002031, Read Quality: Below_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28645A, Total Reads: 19976.0, Normalization Value: 0.005006, Read Quality: Below_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28646A, Total Reads: 119887.0, Normalization Value: 0.000834, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28647A, Total Reads: 96680.0, Normalization Value: 0.001034, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28648A, Total Reads: 246702.0, Normalization Value: 0.000405, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28649A, Total Reads: 235734.0, Normalization Value: 0.000424, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28650A, Total Reads: 183815.0, Normalization Value: 0.000544, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28651A, Total Reads: 191829.0, Normalization Value: 0.000521, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28652A, Total Reads: 279117.0, Normalization Value: 0.000358, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28653A, Total Reads: 334409.0, Normalization Value: 0.000299, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28654A, Total Reads: 269214.0, Normalization Value: 0.000371, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28655A, Total Reads: 310160.0, Normalization Value: 0.000322, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28656A, Total Reads: 129142.0, Normalization Value: 0.000774, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28657A, Total Reads: 246484.0, Normalization Value: 0.000406, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28658A, Total Reads: 156395.0, Normalization Value: 0.000639, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28659A, Total Reads: 226747.0, Normalization Value: 0.000441, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28660A, Total Reads: 249745.0, Normalization Value: 0.000400, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28661A, Total Reads: 191244.0, Normalization Value: 0.000523, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28662A, Total Reads: 43.0, Normalization Value: 2.325581, Read Quality: Below_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28663A, Total Reads: 206380.0, Normalization Value: 0.000485, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28664A, Total Reads: 224101.0, Normalization Value: 0.000446, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28665A, Total Reads: 112131.0, Normalization Value: 0.000892, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28666A, Total Reads: 211180.0, Normalization Value: 0.000474, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28667A, Total Reads: 116454.0, Normalization Value: 0.000859, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28668A, Total Reads: 169696.0, Normalization Value: 0.000589, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28669A, Total Reads: 242540.0, Normalization Value: 0.000412, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28670A, Total Reads: 136815.0, Normalization Value: 0.000731, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28671A, Total Reads: 170216.0, Normalization Value: 0.000587, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28672A, Total Reads: 66931.0, Normalization Value: 0.001494, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28673A, Total Reads: 54.0, Normalization Value: 1.851852, Read Quality: Below_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28674A, Total Reads: 157225.0, Normalization Value: 0.000636, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28675A, Total Reads: 116216.0, Normalization Value: 0.000860, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28676A, Total Reads: 124916.0, Normalization Value: 0.000801, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28677A, Total Reads: 166407.0, Normalization Value: 0.000601, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28678A, Total Reads: 243199.0, Normalization Value: 0.000411, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28679A, Total Reads: 113420.0, Normalization Value: 0.000882, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28680A, Total Reads: 79015.0, Normalization Value: 0.001266, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28681A, Total Reads: 133562.0, Normalization Value: 0.000749, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28682A, Total Reads: 39847.0, Normalization Value: 0.002510, Read Quality: Below_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28683A, Total Reads: 200460.0, Normalization Value: 0.000499, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28684A, Total Reads: 183150.0, Normalization Value: 0.000546, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28685A, Total Reads: 308989.0, Normalization Value: 0.000324, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28686A, Total Reads: 145113.0, Normalization Value: 0.000689, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28687A, Total Reads: 231918.0, Normalization Value: 0.000431, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28688A, Total Reads: 166375.0, Normalization Value: 0.000601, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28689A, Total Reads: 297571.0, Normalization Value: 0.000336, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28690A, Total Reads: 28435.0, Normalization Value: 0.003517, Read Quality: Below_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28691A, Total Reads: 312384.0, Normalization Value: 0.000320, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28692A, Total Reads: 139491.0, Normalization Value: 0.000717, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28693A, Total Reads: 154485.0, Normalization Value: 0.000647, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28694A, Total Reads: 228730.0, Normalization Value: 0.000437, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28695A, Total Reads: 198206.0, Normalization Value: 0.000505, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28696A, Total Reads: 256244.0, Normalization Value: 0.000390, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28697A, Total Reads: 69207.0, Normalization Value: 0.001445, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28698A, Total Reads: 338002.0, Normalization Value: 0.000296, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28699A, Total Reads: 261128.0, Normalization Value: 0.000383, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28700A, Total Reads: 62579.0, Normalization Value: 0.001598, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28701A, Total Reads: 122915.0, Normalization Value: 0.000814, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28702A, Total Reads: 124355.0, Normalization Value: 0.000804, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28703A, Total Reads: 191203.0, Normalization Value: 0.000523, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28704A, Total Reads: 69310.0, Normalization Value: 0.001443, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28705A, Total Reads: 414708.0, Normalization Value: 0.000241, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28706A, Total Reads: 193282.0, Normalization Value: 0.000517, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28707A, Total Reads: 0.0, Normalization Value: 0.000000, Read Quality: Below_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28708A, Total Reads: 443958.0, Normalization Value: 0.000225, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28709A, Total Reads: 218769.0, Normalization Value: 0.000457, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28710A, Total Reads: 27.0, Normalization Value: 3.703704, Read Quality: Below_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28711A, Total Reads: 10.0, Normalization Value: 10.000000, Read Quality: Below_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28712A, Total Reads: 145494.0, Normalization Value: 0.000687, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28713A, Total Reads: 161656.0, Normalization Value: 0.000619, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28714A, Total Reads: 66152.0, Normalization Value: 0.001512, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28715A, Total Reads: 203283.0, Normalization Value: 0.000492, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28716A, Total Reads: 214703.0, Normalization Value: 0.000466, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28717A, Total Reads: 304241.0, Normalization Value: 0.000329, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28718A, Total Reads: 204658.0, Normalization Value: 0.000489, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28719A, Total Reads: 162334.0, Normalization Value: 0.000616, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28720A, Total Reads: 149915.0, Normalization Value: 0.000667, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28721A, Total Reads: 132607.0, Normalization Value: 0.000754, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28722A, Total Reads: 262976.0, Normalization Value: 0.000380, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28723A, Total Reads: 302772.0, Normalization Value: 0.000330, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28724A, Total Reads: 335003.0, Normalization Value: 0.000299, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28725A, Total Reads: 5291669.0, Normalization Value: 0.000019, Read Quality: Above_50000
# File: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_Counts/output_csvs/Counts_BS28726A, Total Reads: 550082.0, Normalization Value: 0.000182, Read Quality: Above_50000
# Summary saved to: /Users/trollj01/PycharmProjects/pythonProject1/20250527_SGE_FinalScripts/Jurkat_Valine/Jurkat_Valine_SummaryOutputs/Jurkat_Val_RelativeReadCounts.csv
